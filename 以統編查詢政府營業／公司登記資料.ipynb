# %% [markdown]
# <a href="https://colab.research.google.com/github/henryho1324/taiwan_business_dat_API/blob/main/%E4%BB%A5%E7%B5%B1%E7%B7%A8%E6%9F%A5%E8%A9%A2%E6%94%BF%E5%BA%9C%E7%87%9F%E6%A5%AD%EF%BC%8F%E5%85%AC%E5%8F%B8%E7%99%BB%E8%A8%98%E8%B3%87%E6%96%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 定義API 串接函數
# 目的：串連政府API，以統編呼叫營業登記、公司登記之資料。

# %%
def tax_id_basic_info(tax_id):
    # import package
    import requests
    
    # variables for f-string
    format = "json"
    President_No = str(tax_id)
    Business_Accounting_NO = str(tax_id)
    
    # 根據商家規模，可分為「商業登記」與「公司登記」
    # try 商業登記
    try:
        # request data

        # taiwan gov open data api: 商業登記基本資料-應用三 (https://reurl.cc/Vj32yy)
        # 「商家負責人」、「資料最後更改日期」等重要資訊存放於「應用一」之中，但必須先透過「應用三」取得 'Agency' 欄位，才可使用「應用一」
        api_str = f"https://data.gcis.nat.gov.tw/od/data/api/426D5542-5F05-43EB-83F9-F1300F14E1F1?$format={format}&$filter=President_No eq {President_No}"
        r = requests.get(api_str, verify=False)
        list_of_dicts = r.json()
        # print(list_of_dicts)
        # get the 'Agency' column for next step
        Agency = list_of_dicts[0]['Agency']

        # taiwan gov open data API: 商業登記基本資料-應用一 (https://reurl.cc/Vj32yy)
        api_str2 = f'https://data.gcis.nat.gov.tw/od/data/api/7E6AFA72-AD6A-46D3-8681-ED77951D912D?$format={format}&$filter=President_No eq {President_No} and Agency eq {Agency}'
    
        # save the info into json format
        r = requests.get(api_str2, verify=False)
        biz_info = r.json()
        # print(biz_info)

        # get the necessary columns from json
        tax_id_is_valid = True
        business_name = biz_info[0]['Business_Name'] # 行號名稱
        responsible_name = biz_info[0]['Responsible_Name'] # 負責人姓名
        business_last_change_datestr = biz_info[0]['Business_Last_Change_Date'] # 最後修改日期
        business_type = biz_info[0]['Business_Organization_Type_Desc'] # 商家類別（獨資、合資 etc.)

        # change the date format from 民國 to A.C. for business_last_change_date
        business_last_change_datestr = str(int(business_last_change_datestr) + 19110000)

        biz_info_dict = {'tax_id': President_No,'tax_id_is_valid':tax_id_is_valid, 'business_name':business_name, 'responsible_name':responsible_name, 
                         'business_type':business_type,'business_last_change_datestr':business_last_change_datestr}
        return biz_info_dict

    except:
        try:
            # taiwan gov open data api: 公司登記基本資料-應用一 (https://reurl.cc/Vj32yy)
            # 公司登記基本資料之API，僅需統編(Business_Accounting_NO) 即可使用
            api_str = f'https://data.gcis.nat.gov.tw/od/data/api/5F64D864-61CB-4D0D-8AD9-492047CC1EA6?$format={format}&$filter=Business_Accounting_NO eq {Business_Accounting_NO}'
            r = requests.get(api_str, verify=False)
            biz_info = r.json()

            tax_id_is_valid = True
            business_name = biz_info[0]['Company_Name'] # 行號名稱
            responsible_name = biz_info[0]['Responsible_Name'] # 負責人姓名
            business_last_change_datestr = biz_info[0]['Change_Of_Approval_Data'] # 最後修改日期

            # change the date format from 民國 to A.C. for business_last_change_date
            business_last_change_datestr = str(int(business_last_change_datestr) + 19110000) 

            biz_info_dict = {'tax_id': President_No, 'tax_id_is_valid':tax_id_is_valid, 'business_name':business_name, 'responsible_name':responsible_name,
                             'business_last_change_datestr':business_last_change_datestr}
            return biz_info_dict
        except:
            tax_id_is_valid = False
            biz_info_dict = {'tax_id': President_No, 'tax_id_is_valid':tax_id_is_valid}
            return biz_info_dict

# %% [markdown]
# #### 自定義函數測試

# %%
# function test
tax_id_basic_info('50819934')
# Out:
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# {'business_last_change_datestr': '20210906',
#  'business_name': '台灣星豆有限公司',
#  'responsible_name': '馬雅芬',
#  'tax_id': '50819934',
#  'tax_id_is_valid': True}

# %% [markdown]
# ### 將 tax_id_basic_info 函數應用於存有統編資料之csv檔

# %%
# import packages
import numpy as np
import pandas as pd
from google.colab import files

# %%
# csv檔資料來源：全國營業(稅籍)登記資料集 (https://data.gov.tw/dataset/9400)
df = pd.read_csv('/content/drive/MyDrive/Data/vat_num/全國營業(稅籍)登記資料集.csv', dtype={'統一編號':str, '總機構統一編號':str})

# 「全國營業(稅籍)登記資料集」中，中小企業之 '總機構統一編號' 為 Null，僅有'統一編號'資料
df['總機構統一編號'] = df['總機構統一編號'].fillna(df['統一編號'])

# 將所有不重複之總機構統編存為list
tax_id_list = df['總機構統一編號'].unique()

# %% [markdown]
# #### 測試 (100 observations)

# %%
# select a 100 observations subset for testing
tax_id_list_short = tax_id_list[0:100]

print(len(tax_id_list_short))
print(tax_id_list_short)
# Out:
# 100
# [nan '38965019' '61194605' '82554400' '47588972' '21822468' '99925659'
#  '19246243' '87004192' '99944261' '25277284' '72397281' '45540235'
#  '89771986' '82551213' '72430556' '91016889' '17713903' '38965257'
#  '45736596' '28921040' '47525098' '10925136' '61432901' '61755042'
#  '87160263' '42586052' '26825181' '34889201' '94927616' '61362905'
#  '39756399' '55891293' '87160828' '45676767' '61410505' '77370108'
#  '42764318' '88561272' '83128593' '55967194' '87003412' '21471364'
#  '84987494' '45593598' '12041266' '99381678' '72597942' '72443665'
#  '85996750' '82376975' '47522228' '61782646' '81507204' '18138479'
#  '25473954' '47590484' '77375618' '82404727' '87159603' '82403305'
#  '87163374' '14605472' '39701114' '87820130' '61502103' '82552331'
#  '84859977' '10920575' '82400877' '12817106' '61918968' '82554295'
#  '39698856' '77385658' '82550397' '38880758' '47353124' '25228159'
#  '14609815' '14603220' '25419220' '82373512' '82551065' '18126847'
#  '88409376' '61799436' '39919106' '87841698' '81509414' '21476229'
#  '87005615' '14613120' '18135162' '81506319' '14610088' '87003503'
#  '88455743' '25321768' '98173286']

# %%
# prepare a empty list to store the output dict from 'tax_id_basic_info' function
list_of_dict = []
for tax_id in tax_id_list_short:
    list_of_dict.append(tax_id_basic_info(tax_id))
    
list_of_dict
# Out:
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# [{'tax_id': 'nan', 'tax_id_is_valid': False},
#  {'business_last_change_datestr': '20150413',
#   'business_name': '原味商行',
#   'business_type': '獨資',
#   'responsible_name': '連麗雀',
#   'tax_id': '38965019',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20180918',
#   'business_name': '和興商店',
#   'business_type': '獨資',
#   'responsible_name': '黃秀英',
#   'tax_id': '61194605',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20191106',
#   'business_name': '啓輝環管企業社',
#   'business_type': '獨資',
#   'responsible_name': '簡裕政',
#   'tax_id': '82554400',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20161101',
#   'business_name': '龍昇工程行',
#   'business_type': '獨資',
#   'responsible_name': '張玉井',
#   'tax_id': '47588972',
#   'tax_id_is_valid': True},
#  {'tax_id': '21822468', 'tax_id_is_valid': False},
#  {'business_last_change_datestr': '20141209',
#   'business_name': '百味香小吃部',
#   'business_type': '獨資',
#   'responsible_name': '蕭英志',
#   'tax_id': '99925659',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20210825',
#   'business_name': '建隆工程行',
#   'business_type': '獨資',
#   'responsible_name': '簡雯文',
#   'tax_id': '19246243',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20200401',
#   'business_name': '月桃香休閒農場',
#   'business_type': '獨資',
#   'responsible_name': '黃國泰',
#   'tax_id': '87004192',
#   'tax_id_is_valid': True},
#  {'tax_id': '99944261', 'tax_id_is_valid': False},
#  {'tax_id': '25277284', 'tax_id_is_valid': False},
#  {'tax_id': '72397281', 'tax_id_is_valid': False},
#  {'business_last_change_datestr': '20071009',
#   'business_name': '金茂電業工程行',
#   'business_type': '獨資',
#   'responsible_name': '溫明詠',
#   'tax_id': '45540235',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20191128',
#   'business_name': '冠宗興業有限公司',
#   'responsible_name': '張瑞懿',
#   'tax_id': '89771986',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20190626',
#   'business_name': '冠富工程企業社',
#   'business_type': '獨資',
#   'responsible_name': '張瑞懿',
#   'tax_id': '82551213',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20180119',
#   'business_name': '捷科工程行',
#   'business_type': '獨資',
#   'responsible_name': '張祐瑋',
#   'tax_id': '72430556',
#   'tax_id_is_valid': True},
#  {'tax_id': '91016889', 'tax_id_is_valid': False},
#  {'tax_id': '17713903', 'tax_id_is_valid': False},
#  {'business_last_change_datestr': '20170621',
#   'business_name': '小島大歌影音工作室',
#   'business_type': '獨資',
#   'responsible_name': '陳玟臻',
#   'tax_id': '38965257',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20081002',
#   'business_name': '溪底遙商行',
#   'business_type': '獨資',
#   'responsible_name': '馮小非',
#   'tax_id': '45736596',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20160316',
#   'business_name': '阿爾發光學有限公司',
#   'responsible_name': '黃朝政',
#   'tax_id': '28921040',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20160923',
#   'business_name': '洞九營地',
#   'business_type': '獨資',
#   'responsible_name': '李國勳',
#   'tax_id': '47525098',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20131113',
#   'business_name': '唐高堆高機行',
#   'business_type': '獨資',
#   'responsible_name': '賴建國',
#   'tax_id': '10925136',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '19900724',
#   'business_name': '隆興米店',
#   'business_type': '獨資',
#   'responsible_name': '許清標',
#   'tax_id': '61432901',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '19760101',
#   'business_name': '興旺商店',
#   'business_type': '獨資',
#   'responsible_name': '張武旺',
#   'tax_id': '61755042',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20200828',
#   'business_name': '天水藏金花藝',
#   'business_type': '獨資',
#   'responsible_name': '邱鎭彬',
#   'tax_id': '87160263',
#   'tax_id_is_valid': True},
#  {'tax_id': '42586052', 'tax_id_is_valid': False},
#  {'business_last_change_datestr': '20160621',
#   'business_name': '一畝田加工坊',
#   'business_type': '獨資',
#   'responsible_name': '鄭曉璇',
#   'tax_id': '26825181',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20210803',
#   'business_name': '油甘先生農產加工場',
#   'business_type': '獨資',
#   'responsible_name': '陳長宏',
#   'tax_id': '34889201',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20170801',
#   'business_name': '億源工程行',
#   'business_type': '獨資',
#   'responsible_name': '張勝華',
#   'tax_id': '94927616',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20141212',
#   'business_name': '復興商店',
#   'business_type': '獨資',
#   'responsible_name': '陳姿嬑',
#   'tax_id': '61362905',
#   'tax_id_is_valid': True},
#  {'tax_id': '39756399', 'tax_id_is_valid': False},
#  {'business_last_change_datestr': '20190530',
#   'business_name': '瑋德生物科技有限公司',
#   'responsible_name': '陳政偉',
#   'tax_id': '55891293',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20200910',
#   'business_name': '久揚工程行',
#   'business_type': '獨資',
#   'responsible_name': '徐雅綺',
#   'tax_id': '87160828',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20210901',
#   'business_name': '旭順水電工程行',
#   'business_type': '獨資',
#   'responsible_name': '廖學崇',
#   'tax_id': '45676767',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20000214',
#   'business_name': '瑞發商店',
#   'business_type': '獨資',
#   'responsible_name': '李碧雲',
#   'tax_id': '61410505',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '19910903',
#   'business_name': '栓發起重行',
#   'business_type': '獨資',
#   'responsible_name': '李炎諭',
#   'tax_id': '77370108',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20170113',
#   'business_name': '東與有限公司',
#   'responsible_name': '郭芳蘭',
#   'tax_id': '42764318',
#   'tax_id_is_valid': True},
#  {'tax_id': '88561272', 'tax_id_is_valid': False},
#  {'tax_id': '83128593', 'tax_id_is_valid': False},
#  {'business_last_change_datestr': '20180605',
#   'business_name': '一畝田健康生技有限公司',
#   'responsible_name': '鄭曉璇',
#   'tax_id': '55967194',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20200305',
#   'business_name': '惜緣農業資材行',
#   'business_type': '獨資',
#   'responsible_name': '陳蘭婷',
#   'tax_id': '87003412',
#   'tax_id_is_valid': True},
#  {'tax_id': '21471364', 'tax_id_is_valid': False},
#  {'business_last_change_datestr': '20210906',
#   'business_name': '旭順工程有限公司',
#   'responsible_name': '廖學崇',
#   'tax_id': '84987494',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20080116',
#   'business_name': '胤力土木包工業',
#   'business_type': '獨資',
#   'responsible_name': '廖彩秀',
#   'tax_id': '45593598',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20020809',
#   'business_name': '青山肥料行',
#   'business_type': '獨資',
#   'responsible_name': '陳徐友妹',
#   'tax_id': '12041266',
#   'tax_id_is_valid': True},
#  {'tax_id': '99381678', 'tax_id_is_valid': False},
#  {'business_last_change_datestr': '20211001',
#   'business_name': '潺潺森活露營區',
#   'business_type': '獨資',
#   'responsible_name': '謝榮家',
#   'tax_id': '72597942',
#   'tax_id_is_valid': True},
#  {'tax_id': '72443665', 'tax_id_is_valid': False},
#  {'tax_id': '85996750', 'tax_id_is_valid': False},
#  {'tax_id': '82376975', 'tax_id_is_valid': False},
#  {'business_last_change_datestr': '20160504',
#   'business_name': '森呼吸肖楠營地',
#   'business_type': '獨資',
#   'responsible_name': '蔡宜靜',
#   'tax_id': '47522228',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20141117',
#   'business_name': '新義成醬園',
#   'business_type': '獨資',
#   'responsible_name': '詹義夫',
#   'tax_id': '61782646',
#   'tax_id_is_valid': True},
#  {'tax_id': '81507204', 'tax_id_is_valid': False},
#  {'business_last_change_datestr': '20030926',
#   'business_name': '中寮巧手工作坊',
#   'business_type': '獨資',
#   'responsible_name': '馬  菊',
#   'tax_id': '18138479',
#   'tax_id_is_valid': True},
#  {'tax_id': '25473954', 'tax_id_is_valid': False},
#  {'business_last_change_datestr': '20170109',
#   'business_name': '佳哉畜牧場',
#   'business_type': '獨資',
#   'responsible_name': '詹孟翰',
#   'tax_id': '47590484',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20190102',
#   'business_name': '中南水電工程行',
#   'business_type': '獨資',
#   'responsible_name': '張立韋',
#   'tax_id': '77375618',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20190425',
#   'business_name': '鼎勝水電工程行',
#   'business_type': '獨資',
#   'responsible_name': '廖仁鼎',
#   'tax_id': '82404727',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20200806',
#   'business_name': '綠齋小吃部',
#   'business_type': '獨資',
#   'responsible_name': '林偉平',
#   'tax_id': '87159603',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20190306',
#   'business_name': '永明企業社',
#   'business_type': '獨資',
#   'responsible_name': '陳志明',
#   'tax_id': '82403305',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20201222',
#   'business_name': '鑫億室內裝修工程行',
#   'business_type': '獨資',
#   'responsible_name': '邱仲助',
#   'tax_id': '87163374',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20210924',
#   'business_name': '瑞豐畜牧場',
#   'business_type': '獨資',
#   'responsible_name': '劉瑞溪',
#   'tax_id': '14605472',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20121211',
#   'business_name': '穩穫農產行',
#   'business_type': '獨資',
#   'responsible_name': '田明和',
#   'tax_id': '39701114',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '19970811',
#   'business_name': '承昕工程行',
#   'business_type': '獨資',
#   'responsible_name': '廖正顯',
#   'tax_id': '87820130',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '19801227',
#   'business_name': '廣豐商店',
#   'business_type': '獨資',
#   'responsible_name': '蔡鳳宇',
#   'tax_id': '61502103',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20190815',
#   'business_name': '久業工程行',
#   'business_type': '獨資',
#   'responsible_name': '洪玉堂',
#   'tax_id': '82552331',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20201103',
#   'business_name': '連春營造有限公司',
#   'responsible_name': '林洪連春',
#   'tax_id': '84859977',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20210423',
#   'business_name': '暘昇工程行',
#   'business_type': '獨資',
#   'responsible_name': '蕭名尉',
#   'tax_id': '10920575',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20190802',
#   'business_name': '誠閤企業社',
#   'business_type': '合夥',
#   'responsible_name': '蔡仲凱',
#   'tax_id': '82400877',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20181030',
#   'business_name': '協鉅營造有限公司',
#   'responsible_name': '陳政忠',
#   'tax_id': '12817106',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20150806',
#   'business_name': '泳源商店',
#   'business_type': '獨資',
#   'responsible_name': '林月足',
#   'tax_id': '61918968',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20191104',
#   'business_name': '太育工程行',
#   'business_type': '獨資',
#   'responsible_name': '張智育',
#   'tax_id': '82554295',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20120903',
#   'business_name': '大川工程行',
#   'business_type': '合夥',
#   'responsible_name': '蔡坤炎',
#   'tax_id': '39698856',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20210505',
#   'business_name': '信興工程行',
#   'business_type': '獨資',
#   'responsible_name': '蔡濡鴻',
#   'tax_id': '77385658',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20190520',
#   'business_name': '戲宵工作室',
#   'business_type': '合夥',
#   'responsible_name': '陳亮帆',
#   'tax_id': '82550397',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20170112',
#   'business_name': '宏勝工程行',
#   'business_type': '獨資',
#   'responsible_name': '陳阿(美色)',
#   'tax_id': '38880758',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20151119',
#   'business_name': '立成搬家起重行',
#   'business_type': '獨資',
#   'responsible_name': '張嘉政',
#   'tax_id': '47353124',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20090828',
#   'business_name': '吳秋植物染工作坊',
#   'business_type': '獨資',
#   'responsible_name': '吳 秋',
#   'tax_id': '25228159',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20021211',
#   'business_name': '廣興雉雞繁殖場',
#   'business_type': '獨資',
#   'responsible_name': '吳  秋',
#   'tax_id': '14609815',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20210504',
#   'business_name': '承軒工程行',
#   'business_type': '獨資',
#   'responsible_name': '游秀滿',
#   'tax_id': '14603220',
#   'tax_id_is_valid': True},
#  {'tax_id': '25419220', 'tax_id_is_valid': False},
#  {'tax_id': '82373512', 'tax_id_is_valid': False},
#  {'business_last_change_datestr': '20210928',
#   'business_name': '品宏農產行',
#   'business_type': '獨資',
#   'responsible_name': '龍品宏',
#   'tax_id': '82551065',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20211026',
#   'business_name': '柳橙林山產行',
#   'business_type': '獨資',
#   'responsible_name': '吳明宙',
#   'tax_id': '18126847',
#   'tax_id_is_valid': True},
#  {'tax_id': '88409376', 'tax_id_is_valid': False},
#  {'business_last_change_datestr': '20180328',
#   'business_name': '金材商號',
#   'business_type': '獨資',
#   'responsible_name': '徐一信',
#   'tax_id': '61799436',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20131203',
#   'business_name': '建榆企業社',
#   'business_type': '獨資',
#   'responsible_name': '黃建平',
#   'tax_id': '39919106',
#   'tax_id_is_valid': True},
#  {'tax_id': '87841698', 'tax_id_is_valid': False},
#  {'business_last_change_datestr': '20210112',
#   'business_name': '財神焊接企業社',
#   'business_type': '獨資',
#   'responsible_name': '黃榆媗',
#   'tax_id': '81509414',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20050224',
#   'business_name': '農陞農藥行',
#   'business_type': '獨資',
#   'responsible_name': '劉文程',
#   'tax_id': '21476229',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20200522',
#   'business_name': '廣昇青果行',
#   'business_type': '獨資',
#   'responsible_name': '謝棕謀',
#   'tax_id': '87005615',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20030908',
#   'business_name': '亞立企業社',
#   'business_type': '獨資',
#   'responsible_name': '呂瑞鳳',
#   'tax_id': '14613120',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20060317',
#   'business_name': '聖峰茶葉行',
#   'business_type': '獨資',
#   'responsible_name': '蕭月鏞',
#   'tax_id': '18135162',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20131021',
#   'business_name': '崇德工程行',
#   'business_type': '獨資',
#   'responsible_name': '徐一信',
#   'tax_id': '81506319',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20210823',
#   'business_name': '品瑄食品',
#   'business_type': '獨資',
#   'responsible_name': '柯 ',
#   'tax_id': '14610088',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20200309',
#   'business_name': '氏修商行',
#   'business_type': '獨資',
#   'responsible_name': '丁氏修',
#   'tax_id': '87003503',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20211020',
#   'business_name': '金栩工程行',
#   'business_type': '獨資',
#   'responsible_name': '張羽淳',
#   'tax_id': '88455743',
#   'tax_id_is_valid': True},
#  {'business_last_change_datestr': '20171024',
#   'business_name': '吉軒水產行',
#   'business_type': '獨資',
#   'responsible_name': '田淑綿',
#   'tax_id': '25321768',
#   'tax_id_is_valid': True},
#  {'tax_id': '98173286', 'tax_id_is_valid': False}]

# %%
# save the business info as DataFrame
api_info_df = pd.DataFrame(list_of_dict)
api_info_df
# Out:
#       tax_id  tax_id_is_valid  ... business_type business_last_change_datestr
# 0        nan            False  ...           NaN                          NaN
# 1   38965019             True  ...            獨資                     20150413
# 2   61194605             True  ...            獨資                     20180918
# 3   82554400             True  ...            獨資                     20191106
# 4   47588972             True  ...            獨資                     20161101
# ..       ...              ...  ...           ...                          ...
# 95  14610088             True  ...            獨資                     20210823
# 96  87003503             True  ...            獨資                     20200309
# 97  88455743             True  ...            獨資                     20211020
# 98  25321768             True  ...            獨資                     20171024
# 99  98173286            False  ...           NaN                          NaN
#
# [100 rows x 6 columns]
